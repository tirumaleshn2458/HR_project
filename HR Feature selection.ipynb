# %% [markdown]
# # HR prediction
#
# ## Feature selection

# %%
import pandas as pd
import numpy as np

# %%
data_frame=pd.read_csv('modified_data.csv')

# %%
data_frame.head()
# Out:
#         Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0  0.683737        1.0   0.885521          0.000000       0.25
# 1  0.831787        0.0   0.374403          0.617540       0.00
# 2  0.598474        1.0   0.967331          0.205847       0.25
# 3  0.503446        0.0   0.972445          0.326260       0.75
# 4  0.336773        0.0   0.653689          0.205847       0.00
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0             1.0            0.0        0.000000                 0.333333
# 1             1.0            0.0        0.090793                 0.666667
# 2             0.2            0.0        0.181587                 1.000000
# 3             1.0            0.0        0.210816                 1.000000
# 4             0.8            0.0        0.254889                 0.000000
#
#    HourlyRate  ...  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0    0.948607  ...            0.222222                 0.000000
# ...

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso

# %%
model=SelectFromModel(Lasso(alpha=0.001,random_state=0))

# %%
x=data_frame.drop(['Attrition'],axis=1)
y=data_frame[['Attrition']]

# %%
model.fit(x,y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.001, random_state=0))

# %%
model.get_support()
# Out:
# array([ True,  True,  True, False,  True, False, False,  True, False,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#        False,  True, False,  True, False,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
features_to_select=[]
for i,j in zip(x.columns,model.get_support()):
    if j==True:
        features_to_select.append(i)

# %%
final_data=pd.concat([data_frame[features_to_select],data_frame[['Attrition']]],axis=1)

# %%
final_data.head()
# Out:
#         Age  DailyRate  DistanceFromHome  EducationField  \
# 0  0.683737   0.885521          0.000000             1.0
# 1  0.831787   0.374403          0.617540             1.0
# 2  0.598474   0.967331          0.205847             0.2
# 3  0.503446   0.972445          0.326260             1.0
# 4  0.336773   0.653689          0.205847             0.8
#
#    EnvironmentSatisfaction  JobInvolvement  JobRole  JobSatisfaction  \
# 0                 0.333333        0.666667    1.000         1.000000
# 1                 0.666667        0.333333    0.875         0.333333
# 2                 1.000000        0.333333    0.750         0.666667
# 3                 1.000000        0.666667    0.875         0.666667
# 4                 0.000000        0.666667    0.750         0.333333
#
#    MonthlyIncome  NumCompaniesWorked  ...  YearsSinceLastPromotion  \
# 0       0.596518            0.888889  ...                 0.000000
# 1       0.544458            0.111111  ...                 0.066667
# ...

# %%
final_data.to_csv('final_data.csv',index=False)
